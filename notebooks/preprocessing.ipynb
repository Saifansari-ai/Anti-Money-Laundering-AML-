# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
df1 = pd.read_csv('/home/saif/Desktop/Anti-Money-Laundering-AML-/data/raw/HI-Small_Trans.csv')

# %%
df1.shape
# Out:
# (5078345, 11)

# %%
df1.sample(5)
# Out:
#                 Timestamp  From Bank    Account  To Bank  Account.1  \
# 1252096  2022/09/02 03:41     137218  80DD91EA0   238845  80E841A00
# 394595   2022/09/01 02:40         12  800156670     1068  800837E10
# 3752875  2022/09/08 00:04     127593  80ADF43E0    27755  80B238850
# 780847   2022/09/01 14:14      11405  801D60CD0    11405  801D60CD0
# 4995331  2022/09/10 13:59       1411  80227E700    17907  80C564EF0
#
#          Amount Received Receiving Currency  Amount Paid   Payment Currency  \
# 1252096            22.43        Swiss Franc        22.43        Swiss Franc
# 394595            342.61          US Dollar       342.61          US Dollar
# 3752875           107.51  Australian Dollar       107.51  Australian Dollar
# 780847             16.30          US Dollar        16.30          US Dollar
# 4995331           410.18          US Dollar       410.18          US Dollar
#
#         Payment Format  Is Laundering
# 1252096    Credit Card              0
# 394595     Credit Card              0
# 3752875    Credit Card              0
# 780847    Reinvestment              0
# 4995331    Credit Card              0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5078345 entries, 0 to 5078344
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Timestamp           object
#  1   From Bank           int64
#  2   Account             object
#  3   To Bank             int64
#  4   Account.1           object
#  5   Amount Received     float64
#  6   Receiving Currency  object
#  7   Amount Paid         float64
#  8   Payment Currency    object
#  9   Payment Format      object
#  10  Is Laundering       int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 426.2+ MB

# %%
df1.describe()
# Out:
#           From Bank       To Bank  Amount Received   Amount Paid  \
# count  5.078345e+06  5.078345e+06     5.078345e+06  5.078345e+06
# mean   4.573057e+04  6.574456e+04     5.988726e+06  4.509273e+06
# std    8.176562e+04  8.409299e+04     1.037183e+09  8.697728e+08
# min    1.000000e+00  1.000000e+00     1.000000e-06  1.000000e-06
# 25%    1.190000e+02  4.259000e+03     1.833700e+02  1.844800e+02
# 50%    9.679000e+03  2.156800e+04     1.411010e+03  1.414540e+03
# 75%    2.862800e+04  1.223320e+05     1.234627e+04  1.229784e+04
# max    3.563030e+05  3.562940e+05     1.046302e+12  1.046302e+12
#
#        Is Laundering
# count   5.078345e+06
# mean    1.019427e-03
# std     3.191219e-02
# min     0.000000e+00
# 25%     0.000000e+00
# 50%     0.000000e+00
# 75%     0.000000e+00
# max     1.000000e+00

# %%
df1.isnull().sum()
# Out:
# Timestamp             0
# From Bank             0
# Account               0
# To Bank               0
# Account.1             0
# Amount Received       0
# Receiving Currency    0
# Amount Paid           0
# Payment Currency      0
# Payment Format        0
# Is Laundering         0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 9

# %% [markdown]
# ## Preprocessing

# %%
# Convert Timestamp to datetime from object
df1['Timestamp'] = pd.to_datetime(df1['Timestamp'])
df1.dtypes
# Out:
# Timestamp             datetime64[ns]
# From Bank                      int64
# Account                       object
# To Bank                        int64
# Account.1                     object
# Amount Received              float64
# Receiving Currency            object
# Amount Paid                  float64
# Payment Currency              object
# Payment Format                object
# Is Laundering                  int64
# dtype: object

# %%
# convert hexadecimal values of account and account.1 to decimal
df1['Account'] = df1['Account'].apply(lambda x: int(x, 16))
df1['Account.1'] = df1['Account.1'].apply(lambda x: int(x, 16))
df1.dtypes
# Out:
# Timestamp             datetime64[ns]
# From Bank                      int64
# Account                        int64
# To Bank                        int64
# Account.1                      int64
# Amount Received              float64
# Receiving Currency            object
# Amount Paid                  float64
# Payment Currency              object
# Payment Format                object
# Is Laundering                  int64
# dtype: object

# %%
df1.head()
# Out:
#             Timestamp  From Bank      Account  To Bank    Account.1  \
# 0 2022-09-01 00:20:00         10  34360704304       10  34360704304
# 1 2022-09-01 00:20:00       3208  34360739200        1  34360742720
# 2 2022-09-01 00:00:00       3209  34360739440     3209  34360739440
# 3 2022-09-01 00:02:00         12  34360741936       12  34360741936
# 4 2022-09-01 00:06:00         10  34360742400       10  34360742400
#
#    Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0          3697.34          US Dollar      3697.34        US Dollar
# 1             0.01          US Dollar         0.01        US Dollar
# 2         14675.57          US Dollar     14675.57        US Dollar
# 3          2806.97          US Dollar      2806.97        US Dollar
# 4         36682.97          US Dollar     36682.97        US Dollar
#
#   Payment Format  Is Laundering
# 0   Reinvestment              0
# 1         Cheque              0
# 2   Reinvestment              0
# 3   Reinvestment              0
# 4   Reinvestment              0

# %%
df1['Receiving Currency'].value_counts()
# Out:
# Receiving Currency
# US Dollar            1879341
# Euro                 1172017
# Swiss Franc           237884
# Yuan                  206551
# Shekel                194988
# Rupee                 192065
# UK Pound              181255
# Ruble                 157361
# Yen                   156319
# Bitcoin               148151
# Canadian Dollar       141357
# Australian Dollar     138511
# Mexican Peso          111030
# Saudi Riyal            89971
# Brazil Real            71544
# Name: count, dtype: int64

# %%
# Apply lable encoding to Receiving Currency and Payment Currency columns
recv_le = LabelEncoder()
df1['Receiving Currency'] = recv_le.fit_transform(df1['Receiving Currency'])

# %%
df1.head()
# Out:
#             Timestamp  From Bank      Account  To Bank    Account.1  \
# 0 2022-09-01 00:20:00         10  34360704304       10  34360704304
# 1 2022-09-01 00:20:00       3208  34360739200        1  34360742720
# 2 2022-09-01 00:00:00       3209  34360739440     3209  34360739440
# 3 2022-09-01 00:02:00         12  34360741936       12  34360741936
# 4 2022-09-01 00:06:00         10  34360742400       10  34360742400
#
#    Amount Received  Receiving Currency  Amount Paid Payment Currency  \
# 0          3697.34                  12      3697.34        US Dollar
# 1             0.01                  12         0.01        US Dollar
# 2         14675.57                  12     14675.57        US Dollar
# 3          2806.97                  12      2806.97        US Dollar
# 4         36682.97                  12     36682.97        US Dollar
#
#   Payment Format  Is Laundering
# 0   Reinvestment              0
# 1         Cheque              0
# 2   Reinvestment              0
# 3   Reinvestment              0
# 4   Reinvestment              0

# %%
pay_le = LabelEncoder()
df1['Payment Currency'] = pay_le.fit_transform(df1['Payment Currency'])
df1.head()
# Out:
#             Timestamp  From Bank      Account  To Bank    Account.1  \
# 0 2022-09-01 00:20:00         10  34360704304       10  34360704304
# 1 2022-09-01 00:20:00       3208  34360739200        1  34360742720
# 2 2022-09-01 00:00:00       3209  34360739440     3209  34360739440
# 3 2022-09-01 00:02:00         12  34360741936       12  34360741936
# 4 2022-09-01 00:06:00         10  34360742400       10  34360742400
#
#    Amount Received  Receiving Currency  Amount Paid  Payment Currency  \
# 0          3697.34                  12      3697.34                12
# 1             0.01                  12         0.01                12
# 2         14675.57                  12     14675.57                12
# 3          2806.97                  12      2806.97                12
# 4         36682.97                  12     36682.97                12
#
#   Payment Format  Is Laundering
# 0   Reinvestment              0
# 1         Cheque              0
# 2   Reinvestment              0
# 3   Reinvestment              0
# 4   Reinvestment              0

# %%
# Save encoders for later inference
joblib.dump(recv_le, '/home/saif/Desktop/Anti-Money-Laundering-AML-/models/encoders_for_currency/recv_le.pkl')
joblib.dump(pay_le, '/home/saif/Desktop/Anti-Money-Laundering-AML-/models/encoders_for_currency/pay_le.pkl')
# Out:
# ['/home/saif/Desktop/Anti-Money-Laundering-AML-/models/encoders_for_currency/pay_le.pkl']

# %%
# check what currency got which label
recv_le.classes_
# Out:
# array(['Australian Dollar', 'Bitcoin', 'Brazil Real', 'Canadian Dollar',
#        'Euro', 'Mexican Peso', 'Ruble', 'Rupee', 'Saudi Riyal', 'Shekel',
#        'Swiss Franc', 'UK Pound', 'US Dollar', 'Yen', 'Yuan'],
#       dtype=object)

# %%
pay_le.classes_
# Out:
# array(['Australian Dollar', 'Bitcoin', 'Brazil Real', 'Canadian Dollar',
#        'Euro', 'Mexican Peso', 'Ruble', 'Rupee', 'Saudi Riyal', 'Shekel',
#        'Swiss Franc', 'UK Pound', 'US Dollar', 'Yen', 'Yuan'],
#       dtype=object)

# %%
df1.head()
# Out:
#             Timestamp  From Bank      Account  To Bank    Account.1  \
# 0 2022-09-01 00:20:00         10  34360704304       10  34360704304
# 1 2022-09-01 00:20:00       3208  34360739200        1  34360742720
# 2 2022-09-01 00:00:00       3209  34360739440     3209  34360739440
# 3 2022-09-01 00:02:00         12  34360741936       12  34360741936
# 4 2022-09-01 00:06:00         10  34360742400       10  34360742400
#
#    Amount Received  Receiving Currency  Amount Paid  Payment Currency  \
# 0          3697.34                  12      3697.34                12
# 1             0.01                  12         0.01                12
# 2         14675.57                  12     14675.57                12
# 3          2806.97                  12      2806.97                12
# 4         36682.97                  12     36682.97                12
#
#   Payment Format  Is Laundering
# 0   Reinvestment              0
# 1         Cheque              0
# 2   Reinvestment              0
# 3   Reinvestment              0
# 4   Reinvestment              0

# %%
df1['Payment Format'].value_counts()
# Out:
# Payment Format
# Cheque          1864331
# Credit Card     1323324
# ACH              600797
# Cash             490891
# Reinvestment     481056
# Wire             171855
# Bitcoin          146091
# Name: count, dtype: int64

# %%
# apply label encoding on payment format
pay_format_le = LabelEncoder()
df1['Payment Format'] = pay_format_le.fit_transform(df1['Payment Format'])
df1.head()
# Out:
#             Timestamp  From Bank      Account  To Bank    Account.1  \
# 0 2022-09-01 00:20:00         10  34360704304       10  34360704304
# 1 2022-09-01 00:20:00       3208  34360739200        1  34360742720
# 2 2022-09-01 00:00:00       3209  34360739440     3209  34360739440
# 3 2022-09-01 00:02:00         12  34360741936       12  34360741936
# 4 2022-09-01 00:06:00         10  34360742400       10  34360742400
#
#    Amount Received  Receiving Currency  Amount Paid  Payment Currency  \
# 0          3697.34                  12      3697.34                12
# 1             0.01                  12         0.01                12
# 2         14675.57                  12     14675.57                12
# 3          2806.97                  12      2806.97                12
# 4         36682.97                  12     36682.97                12
#
#    Payment Format  Is Laundering
# 0               5              0
# 1               3              0
# 2               5              0
# 3               5              0
# 4               5              0

# %%
pay_format_le.classes_
# Out:
# array(['ACH', 'Bitcoin', 'Cash', 'Cheque', 'Credit Card', 'Reinvestment',
#        'Wire'], dtype=object)

# %%
# save encoders for later inference
joblib.dump(pay_format_le, '/home/saif/Desktop/Anti-Money-Laundering-AML-/models/encoders_for_currency/pay_format_le.pkl')
# Out:
# ['/home/saif/Desktop/Anti-Money-Laundering-AML-/models/encoders_for_currency/pay_format_le.pkl']

# %%
# save preprocessed data into data/processed
df1.to_csv('/home/saif/Desktop/Anti-Money-Laundering-AML-/data/processed/trans_processed_data.csv', index=False)
